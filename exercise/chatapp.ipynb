# %%
# !FLASK_APP=playground.app:app flask run --debug
# Out:
#  * Serving Flask app 'playground.app:app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 111-673-579
# 127.0.0.1 - - [10/Jun/2026 10:19:39] "POST / HTTP/1.1" 200 -

# %%
# !APP_ENV=.env-mitm FLASK_APP=playground.app:app flask run --debug
# Out:
#  * Serving Flask app 'playground.app:app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 111-673-579
