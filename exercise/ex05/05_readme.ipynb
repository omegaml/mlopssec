# %% [markdown]
# Ex 05
# =====
#
# Ziel: Nachvollziehbar alle Aktionen aufzeichnen - ein sog. Audit Log
#
# Schritte:
#
# 1. In `playground/llm.py` den folgenden Code hinzufügen bzw. aktivieren:
#
#    ```
#    # ex05
#    from ex05.auditlog import generate_auditlog
#    generate_auditlog(messages, data["choices"])
#    ```
#
# 2. Studiere die Funktionsweise von `generate_auditlog` => was passiert hier?
#
# 3. Gebe einige Prompts ein, die Datei `audit.log` enthält die entsprechenden Log-Einträge
