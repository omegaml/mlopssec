# %% [markdown]
# Ex 07
# =====
#
# Ziel: SBOM erstellen und analysieren
#
# Schritte
#
# 1. Führe die nachstehende Zelle mit `pip audit` aus => was siehst Du?
# 2. Suche die CVE Einträge für ein Library (z.B. urllib3) und bewerte, ob sie ein Risiko darstellen
# 3. Gehe zur nächsten Zelle und erstelle eine SBOM im CycloneDX Format
# 4. Siehe die letzte Zelle für ein Tool-Beispiel

# %%
# !pip-audit
# Out:
# \ Skipping conda: Dependency not found on PyPI and could not be audited: conda
# | Skipping conda-libmamba-solver: Dependency not found on PyPI and could not be
# \ Skipping de_core_news_sm: Dependency not found on PyPI and could not be
# / Skipping en_core_web_lg: Dependency not found on PyPI and could not be
# - Skipping en_core_web_sm: Dependency not found on PyPI and could not be
# | Skipping libmambapy: Dependency not found on PyPI and could not be audited:
# | Skipping menuinst: Dependency not found on PyPI and could not be audited:
# \ Skipping torch: Dependency not found on PyPI and could not be audited: torch
# | Auditing zstandard (0.25.0)0)5)).15)5)18)8)
# Found 16 known vulnerabilities in 8 packages
# Name      Version ID             Fix Versions
# --------- ------- -------------- ------------
# aiohttp   3.13.5  CVE-2026-34993 3.14.0
# aiohttp   3.13.5  CVE-2026-47265 3.14.0
# brotli    1.1.0   CVE-2025-6176  1.2.0
# diskcache 5.6.3   CVE-2025-69872
# ...

# %%
# !pip-audit --format cyclonedx-json -o pip-audit.cdx.json
# Out:
# \ Skipping conda: Dependency not found on PyPI and could not be audited: conda
# / Skipping conda-libmamba-solver: Dependency not found on PyPI and could not be
# - Skipping de_core_news_sm: Dependency not found on PyPI and could not be
# \ Skipping en_core_web_lg: Dependency not found on PyPI and could not be
# | Skipping en_core_web_sm: Dependency not found on PyPI and could not be
# \ Skipping libmambapy: Dependency not found on PyPI and could not be audited:
# / Skipping menuinst: Dependency not found on PyPI and could not be audited:
# \ Skipping torch: Dependency not found on PyPI and could not be audited: torch
# | Auditing zstandard (0.25.0)0)5)).15)5)18)8)
# Found 16 known vulnerabilities in 8 packages

# %% [markdown]
# ### Mit Tools effizienter arbeiten
#
# 1. Terminal öffnen
# 2. Analyse mit bogrod -W pip-audit.cdx.json
# 3. SBOM ist mit VEX Daten ergänzt
#
# Tipp: bogrod in eigenem Python venv (ausserhalb Docker) installieren - nützlicher
