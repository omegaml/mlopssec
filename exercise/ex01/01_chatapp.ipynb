# %% [markdown]
# Ex 01
# =====
#
# Ziel: Grundversion des Chatbots starten
#
# Wir haben zwei Möglichkeiten
#
# * Variante A: Start mit direkter Verbindung zu openrouter.ai
# * Variante B: Start mit indirekter Verbindung über mitmproxy (damit wir sehen können, was verschickt wird)
#
# Referenzen
#
# * Flask https://flask.palletsprojects.com/en/stable/
# * mitmproxy https://mitmproxy.org/
# * openrouter chat completions https://openrouter.ai/docs/api/api-reference/chat/send-chat-completion-request
# * openai chat completions https://developers.openai.com/api/reference/resources/chat/subresources/completions/methods/create

# %%
# setze als erstes Deinen ApiKey
import os
os.environ.setdefault('LLM_API_KEY', 'DEIN APIKEY') is not None
# Out:
# True

# %% [markdown]
# ### Variante A: start der App mit direkter Verbindung
#
# 1. die nächste Zelle ausführen

# %%
# !export PYTHONPATH=$HOME/mlopssec/exercise FLASK_APP=playground:app; flask run --debug
# Out:
#  * Serving Flask app 'playground:app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661

# %% [markdown]
# ### Variante B: start der App mit indirekter Verbindung
#
# 1. Terminal oeffenen und folgenden Befehl eingeben
#
#       ```
#       $ mitmweb --mode reverse:https://openrouter.ai@8180
#       ```
#
# 3. den angezeigten Link öffnen (siehe Terminal Output => oeffenet mitmproxy web)
# 4. App starten (nächste Zelle)
#
# 5. Im mitmproxy web im Tab "Flow" werden die Verbindungen angezeigt

# %%
# !export PYTHONPATH=$HOME/mlopssec/exercise APP_ENV=.env-mitm FLASK_APP=playground.app; flask run --debug
# Out:
#  * Serving Flask app 'playground.app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
# 127.0.0.1 - - [10/Jun/2026 20:03:34] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:04:23] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:10:02] "POST /reset HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Jun/2026 20:10:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:10:14] "POST / HTTP/1.1" 200 -
#  * Detected change in '/home/jovyan/mlopssec/exercise/playground/__init__.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
#  * Detected change in '/home/jovyan/mlopssec/exercise/ex02/.ipynb_checkpoints/login-checkpoint.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
#  * Detected change in '/home/jovyan/mlopssec/exercise/playground/.ipynb_checkpoints/__init__-checkpoint.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
# 127.0.0.1 - - [10/Jun/2026 20:11:59] "GET /logout HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Jun/2026 20:12:00] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:18] "POST /reset HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Jun/2026 20:12:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:19] "GET / HTTP/1.1" 200 -
#  * Detected change in '/home/jovyan/mlopssec/exercise/playground/.ipynb_checkpoints/__init__-checkpoint.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
#  * Detected change in '/home/jovyan/mlopssec/exercise/playground/.ipynb_checkpoints/__init__-checkpoint.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
# 127.0.0.1 - - [10/Jun/2026 20:12:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:12:33] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:15:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:15:14] "GET / HTTP/1.1" 200 -
#  * Detected change in '/home/jovyan/mlopssec/exercise/playground/__init__.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 140-049-661
# 127.0.0.1 - - [10/Jun/2026 20:15:21] "GET / HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Jun/2026 20:15:21] "GET /login?next=/ HTTP/1.1" 401 -
# 127.0.0.1 - - [10/Jun/2026 20:15:26] "POST /login?next=/ HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Jun/2026 20:15:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Jun/2026 20:15:33] "POST / HTTP/1.1" 200 -
