# %% [markdown]
# Ex 01
# =====
#
# Ziel: Grundversion des Chatbots starten
#
# Wir haben zwei Möglichkeiten
#
# * Variante A: Start mit direkter Verbindung zu openrouter.ai
# * Variante B: Start mit indirekter Verbindung über mitmproxy (damit wir sehen können, was verschickt wird)
#
# Referenzen
#
# * Flask https://flask.palletsprojects.com/en/stable/
# * mitmproxy https://mitmproxy.org/
# * openrouter chat completions https://openrouter.ai/docs/api/api-reference/chat/send-chat-completion-request
# * openai chat completions https://developers.openai.com/api/reference/resources/chat/subresources/completions/methods/create

# %%
# setze als erstes Deinen ApiKey hier oder trage diesen in ../.env und ../.env-mitm ein
# Alternativ vor dem start von Jupyter Lab: 
# $ export LLM_API_KEY="<key>"; jupyter lab
import os
os.environ.setdefault('LLM_API_KEY', 'DEIN OPENROUTER_API_KEY') is not None
# Out:
# True

# %% [markdown]
# ### Variante A: start der App mit direkter Verbindung
#
# 1. die nächste Zelle ausführen

# %%
# !export PYTHONPATH=$PWD/.. FLASK_APP=playground:app; flask run -h 0.0.0.0 --debug
# Out:
#  * Serving Flask app 'playground:app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.17.0.4:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 102-214-988
# 172.17.0.1 - - [11/Jun/2026 08:23:10] "GET / HTTP/1.1" 200 -
# 172.17.0.1 - - [11/Jun/2026 08:23:16] "POST / HTTP/1.1" 200 -
# ^C

# %% [markdown]
# ### Variante B: start der App mit indirekter Verbindung
#
# 1. Terminal oeffenen und folgenden Befehl eingeben
#
#       ```
#       $ mitmweb --mode reverse:https://openrouter.ai@8180 --web-host 0.0.0.0
#       ```
#       <br>
#
# 3. den angezeigten Link öffnen (siehe Terminal Output => oeffenet mitmproxy web)
# 4. App starten (nächste Zelle)
#
# 5. Im mitmproxy web im Tab "Flow" werden die Verbindungen angezeigt

# %%
# !export PYTHONPATH=$PWD/.. APP_ENV=.env-mitm FLASK_APP=playground.app; flask run -h 0.0.0.0 --debug
# Out:
#  * Serving Flask app 'playground.app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.17.0.4:5000
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 102-214-988
# 172.17.0.1 - - [11/Jun/2026 08:24:12] "POST / HTTP/1.1" 200 -
